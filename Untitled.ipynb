# %%
import pandas as pd

# %%
myloan = pd.read_csv('Loan_Default.csv')

# %%
myloan
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import pandas as pd

# %%
myloan
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
myloan = pd.read_csv('Loan_Default.csv')

# %%
myloan
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
myloan['Gender'].value_counts().plot(kind='bar',fig = (12,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
myloan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
Gender = myloan['Gender']
GenderList = list(Gender)

loantype = myloan['loan_type']
Loantypelist = list(loantype)


Gender_and_LoanType = list(zip(Loantypelist,GenderList))

print(Gender_and_LoanType)

Type1_Male = []
Type1_Female = []
Type1_Joint = []
Type1_SexNotAvailable = []



for x,y in Gender_and_LoanType:
    if x == 'Type1' and y == 'Male':
        Type1_Male.append(y)
    if x == 'Type1' and y == 'Female':
        Type1_Female.append(y)
    if x == 'Type1' and y == 'Joint':
        Type1_Joint.append(y)
    if x == 'Type1' and y == 'Sex Not Available':
        Type1_SexNotAvailable.append(y)

print(Type1_Male)
print(Type1_Female)
print(Type1_Joint)
print(Type1_SexNotAvailable)

print("The Male who takes type 1 are:", len(Type1_Male))

set(myloan['loan_type'])
set(myloan['Gender'])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {'Female', 'Joint', 'Male', 'Sex Not Available'}

# %%
Gender = myloan['Gender']
GenderList = list(Gender)

loantype = myloan['loan_type']
Loantypelist = list(loantype)


Gender_and_LoanType = list(zip(Loantypelist,GenderList))

def Type1():

    Type1_Male = []
    Type1_Female = []
    Type1_Joint = []
    Type1_SexNotAvailable = []



    for x,y in Gender_and_LoanType:
        if x == 'type1' and y == 'Male':
            Type1_Male.append(y)
        if x == 'type1' and y == 'Female':
            Type1_Female.append(y)
        if x == 'type1' and y == 'Joint':
            Type1_Joint.append(y)
        if x == 'type1' and y == 'Sex Not Available':
            Type1_SexNotAvailable.append(y)

    print("The Male who takes type 1 are:", len(Type1_Male))
    print("The Female who takes type 1 are:", len(Type1_Female))
    print("The Joint who takes type 1 are:", len(Type1_Joint))
    print("The 'sex not available' who takes type 1 are:", len(Type1_SexNotAvailable))

Type1()
# Out:
# The Male who takes type 1 are: 31591
# The Female who takes type 1 are: 21847
# The Joint who takes type 1 are: 31762
# The 'sex not available' who takes type 1 are: 27973

# %%
def Type2():

    Type2_Male = []
    Type2_Female = []
    Type2_Joint = []
    Type2_SexNotAvailable = []



    for x,y in Gender_and_LoanType:
        if x == 'type2' and y == 'Male':
            Type2_Male.append(y)
        if x == 'type2' and y == 'Female':
            Type2_Female.append(y)
        if x == 'type2' and y == 'Joint':
            Type2_Joint.append(y)
        if x == 'type2' and y == 'Sex Not Available':
            Type2_SexNotAvailable.append(y)

    print("The Male who takes type2 are:", len(Type2_Male))
    print("The Female who takes type2 are:", len(Type2_Female))
    print("The Joint who takes type2 are:", len(Type2_Joint))
    print("The 'sex not available' who takes type2 are:", len(Type2_SexNotAvailable))

Type2()
# Out:
# The Male who takes type2 are: 5701
# The Female who takes type2 are: 4544
# The Joint who takes type2 are: 4926
# The 'sex not available' who takes type2 are: 5591

# %%
def type3():

    type3_Male = []
    type3_Female = []
    type3_Joint = []
    type3_SexNotAvailable = []



    for x,y in Gender_and_LoanType:
        if x == 'type3' and y == 'Male':
            type3_Male.append(y)
        if x == 'type3' and y == 'Female':
            type3_Female.append(y)
        if x == 'type3' and y == 'Joint':
            type3_Joint.append(y)
        if x == 'type3' and y == 'Sex Not Available':
            type3_SexNotAvailable.append(y)

    print("The Male who takes type3 are:", len(type3_Male))
    print("The Female who takes type3 are:", len(type3_Female))
    print("The Joint who takes type3 are:", len(type3_Joint))
    print("The 'sex not available' who takes type3 are:", len(type3_SexNotAvailable))

type3()
# Out:
# The Male who takes type3 are: 5054
# The Female who takes type3 are: 875
# The Joint who takes type3 are: 4711
# The 'sex not available' who takes type3 are: 4095

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for product sales across months
loantypes = ['Type 1', 'Type 2', 'Type 3']
Male = [31591, 5701, 5054]
Female = [21847, 4544, 875]
Joint = [31762, 4926, 4711]
Sex_Not_Available = [27973, 5591, 4095]

# Create an array for the x-axis positions
x = np.arange(len(loantypes))


# Create a bar graph for each product
plt.bar(x-0.2, Male, width=0.2, label='Male', color='b')
plt.bar(x, Female, width=0.2, label='Female', color='g')
plt.bar(x+0.2, Joint, width=0.2, label='Joint', color='r')
plt.bar(x+0.4, Sex_Not_Available, width=0.2, label='Sex_Not_Available', color='y')

# Add labels and title
plt.xlabel('Loan Types')
plt.ylabel('Gender')
plt.title('Gender against Type')
plt.xticks(x, loantypes)  # Set x-axis labels

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.bar(, Type1_Male, width=bar_width, label='Product 1', color='b')
plt.bar(x, product2_sales, width=bar_width, label='Product 2', color='g')
plt.bar(x + bar_width, product3_sales, width=bar_width, label='Product 3', color='r')
